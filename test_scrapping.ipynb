# %%
from scrapping import Crawler
site_crawler = Crawler()

# %%
site_crawler.scrap(["https://shop.mtn.bj"])
# Out:
# Erreur lors de l'extraction des détails du produit 'Casque Moxom Bass noir bluetooth MX WL06' : 'NoneType' object has no attribute 'get_text'
# Aucun produit n'a été trouvé ou tous sont déjà scrappés.
# No data was collected from the provided URLs.

# %%
site_crawler.scrap(["http://carisowo.com/", "https://shop.mtn.bj"])
# Out:
# Scraping produits de la catégorie : Voitures
# Scraping page : http://carisowo.com//petites-annonces-voitures.html
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=2
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=3
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=4
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=5
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=6
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=7
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=8
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=9
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=10
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=11
# Scraping page : http://carisowo.com//petites-annonces-voitures.html?page=12
# ...

# %%
import pandas as pd
data = pd.read_csv("scraped_data.csv")
data.head()
# Out:
#    Unnamed: 0                 Titre    Prix_normal  \
# 0           0        2020 Acura MDX  5 300 000 CFA
# 1           1  2012 Honda Ridgeline  6 500 000 CFA
# 2           2   2004 Toyota Corolla  1 450 000 CFA
# 3           3     2008 Toyota Yaris  3 800 000 CFA
# 4           4           2017 BMW X1  8 900 000 CFA
#
#                                          Description Localisation_bien  \
# 0  2020 Acura MDX, SUV., Contact for more informa...        Porto Novo
# 1  Honda ridgeline, Année 2012, Moteur 6 cylindre...           Cotonou
# 2                        Opportunité consommateurs !           Cotonou
# 3  Toyota Yaris, Année 2008, Série CF, Boîte auto...           Cotonou
# 4  NEW BMW limited, Année 2017, Boîte automatique...           Cotonou
#
#                                         Lien_produit  Lien_images Catégorie  \
# 0  http://carisowo.com//fr/vehicle_listings/annon...          NaN  Voitures
# ...

# %%
data["Prix_normal"]
# Out:
# 0       5 300 000 CFA
# 1       6 500 000 CFA
# 2       1 450 000 CFA
# 3       3 800 000 CFA
# 4       8 900 000 CFA
#             ...
# 7664         7 500CFA
# 7665        50 000CFA
# 7666           100CFA
# 7667        12 000CFA
# 7668        50 000CFA
# Name: Prix_normal, Length: 7669, dtype: object

# %%
# %python3 dashboard.py
# Out:
# UsageError: Line magic function `%python3` not found (But cell magic `%%python3` exists, did you mean that instead?).

# %%
import sys
